# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
epsilon = 2e-16
x_range = np.arange(1e-5, 1e0+1e-5, 1e-5)

# %%
fig, ax = plt.subplots()
ax.loglog(x_range, x_range**6/60480, label = 'Truncation error')
ax.loglog(x_range, 6*(epsilon-1)/x_range**2, label = 'Rounding error')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('error')
# Out:
# Text(0, 0.5, 'error')
